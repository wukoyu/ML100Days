# %%
import requests

# %%
response = requests.get("http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement")
print(response.status_code)
# Out:
# 200

# %%
response = requests.get("http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement")
print(response)
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# <Response [200]>

# %%
https://sta.ci.taiwan.gov.tw/STA_WaterResource_v2/v1.0/Datastreams(3424)/Sensor
# Out:
#   File "<ipython-input-18-a2729e7a3bfb>", line 1
#     https://sta.ci.taiwan.gov.tw/STA_WaterResource_v2/v1.0/Datastreams(3424)/Sensor
#           ^
# SyntaxError: invalid syntax

# %%
import pprint

# URL for the API
url = "https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/"

# POST the request to the server
response = requests.get(url)
# GET the response from the server and grab the json
result = response.json()

# Using pprint to show the beauty format
# You can use print also
pprint.pprint(result)
# Out:
# {'value': [{'name': 'Datastreams',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams'},
#            {'name': 'MultiDatastreams',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/MultiDatastreams'},
#            {'name': 'FeaturesOfInterest',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/FeaturesOfInterest'},
#            {'name': 'HistoricalLocations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/HistoricalLocations'},
#            {'name': 'Locations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Locations'},
#            {'name': 'Observations',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Observations'},
#            {'name': 'ObservedProperties',
#             'url': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/ObservedProperties'},
#            {'name': 'Sensors',
# ...

# %%
import json
response = requests.get("https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams")
print(response.json())
# Out:
# {'@iot.nextLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams?$skip=100', 'value': [{'name': 'SO2', 'description': '二氧化硫 SO2', 'observationType': 'http://www.opengis.net/def/observationType/OGC-OM/2.0/OM_Measurement', 'unitOfMeasurement': {'name': 'parts per billion', 'symbol': 'ppb', 'definition': 'https://en.wikipedia.org/wiki/Parts-per_notation'}, 'phenomenonTime': '2020-09-22T21:00:00.000Z/2020-12-19T14:00:00.000Z', 'Sensor@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams(120)/Sensor', 'ObservedProperty@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams(120)/ObservedProperty', 'Thing@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams(120)/Thing', 'Observations@iot.navigationLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams(120)/Observations', '@iot.id': 120, '@iot.selfLink': 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datas
# ...
